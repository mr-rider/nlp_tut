# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2022-06-05 13:53:03--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 172.67.186.54, 104.21.92.44, 2606:4700:3033::ac43:ba36, ...
# Connecting to www.manythings.org (www.manythings.org)|172.67.186.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14819554 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.13M  5.24MB/s    in 2.7s
#
# 2022-06-05 13:53:06 (5.24 MB/s) - ‘rus-eng.zip’ saved [14819554/14819554]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 71M
# drwxr-xr-x 2 root root 4.0K Jun  5 13:53 .
# drwxr-xr-x 1 root root 4.0K Jun  5 13:53 ..
# -rw-r--r-- 1 root root 1.5K May  2 01:29 _about.txt
# -rw-r--r-- 1 root root  71M May  2 01:29 rus.txt

# %%
# Download the file
path_to_file = '/content/rus-eng/rus.txt'

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eq: "he is a boy." => "he is a boy ."
  w = re.sub(r"([?.!,])", r" \1", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Za-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]

def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]] for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (444587, 444587)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4 ----> я
# 29 ----> очень
# 49 ----> по
# 33 ----> вам
# 413 ----> скучаю
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> i
# 186 ----> miss
# 7 ----> you
# 47 ----> very
# 161 ----> much
# 3 ----> .
# 2 ----> <end>

# %%
# Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 10]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    
  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state=hidden)
    output = tf.reshape(output, (-1, output.shape[2]))
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)), sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7334])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %%
# define the optimizer and the loss function

optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none'
)

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/nlp_tut/lesson10'

# %%
checkpoint_dir = path + '/training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 5.2423
# Epoch 1 Batch 100 Loss 2.2486
# Epoch 1 Batch 200 Loss 2.0267
# Epoch 1 Batch 300 Loss 1.8994
# Epoch 1 Batch 400 Loss 1.7087
# Epoch 1 Batch 500 Loss 1.4813
# Epoch 1 Batch 600 Loss 1.4782
# Epoch 1 Batch 700 Loss 1.3033
# Epoch 1 Batch 800 Loss 1.3737
# Epoch 1 Batch 900 Loss 1.2054
# Epoch 1 Batch 1000 Loss 1.2751
# Epoch 1 Batch 1100 Loss 1.1856
# Epoch 1 Batch 1200 Loss 1.0277
# Epoch 1 Loss 1.5671
# Time taken for 1 epoch 61.877379179000854 sec
#
# Epoch 2 Batch 0 Loss 0.8992
# Epoch 2 Batch 100 Loss 0.9534
# Epoch 2 Batch 200 Loss 0.8089
# Epoch 2 Batch 300 Loss 0.9217
# Epoch 2 Batch 400 Loss 0.8780
# Epoch 2 Batch 500 Loss 0.8116
# Epoch 2 Batch 600 Loss 0.8378
# Epoch 2 Batch 700 Loss 0.7157
# Epoch 2 Batch 800 Loss 0.6904
# Epoch 2 Batch 900 Loss 0.7400
# Epoch 2 Batch 1000 Loss 0.6742
# Epoch 2 Batch 1100 Loss 0.6920
# Epoch 2 Batch 1200 Loss 0.6185
# Epoch 2 Loss 0.7860
# Time taken for 1 epoch 53.74366474151611 sec
#
# Epoch 3 Batch 0 Loss 0.4196
# Epoch 3 Batch 100 Loss 0.4546
# Epoch 3 Batch 200 Loss 0.4105
# Epoch 3 Batch 300 Loss 0.4978
# Epoch 3 Batch 400 Loss 0.5538
# Epoch 3 Batch 500 Loss 0.4316
# Epoch 3 Batch 600 Loss 0.4786
# Epoch 3 Batch 700 Loss 0.4052
# Epoch 3 Batch 800 Loss 0.5648
# Epoch 3 Batch 900 Loss 0.5162
# Epoch 3 Batch 1000 Loss 0.4085
# Epoch 3 Batch 1100 Loss 0.4132
# Epoch 3 Batch 1200 Loss 0.5069
# Epoch 3 Loss 0.4301
# Time taken for 1 epoch 54.474557638168335 sec
#
# Epoch 4 Batch 0 Loss 0.2448
# Epoch 4 Batch 100 Loss 0.2099
# Epoch 4 Batch 200 Loss 0.2044
# Epoch 4 Batch 300 Loss 0.2832
# Epoch 4 Batch 400 Loss 0.2190
# Epoch 4 Batch 500 Loss 0.2632
# Epoch 4 Batch 600 Loss 0.3384
# Epoch 4 Batch 700 Loss 0.2803
# Epoch 4 Batch 800 Loss 0.2440
# Epoch 4 Batch 900 Loss 0.3032
# Epoch 4 Batch 1000 Loss 0.2387
# Epoch 4 Batch 1100 Loss 0.2986
# Epoch 4 Batch 1200 Loss 0.2505
# Epoch 4 Loss 0.2580
# Time taken for 1 epoch 55.19736289978027 sec
#
# Epoch 5 Batch 0 Loss 0.1838
# Epoch 5 Batch 100 Loss 0.1316
# Epoch 5 Batch 200 Loss 0.1802
# Epoch 5 Batch 300 Loss 0.1698
# Epoch 5 Batch 400 Loss 0.1669
# Epoch 5 Batch 500 Loss 0.1704
# Epoch 5 Batch 600 Loss 0.1726
# Epoch 5 Batch 700 Loss 0.1955
# Epoch 5 Batch 800 Loss 0.1908
# Epoch 5 Batch 900 Loss 0.1757
# Epoch 5 Batch 1000 Loss 0.1823
# Epoch 5 Batch 1100 Loss 0.2155
# Epoch 5 Batch 1200 Loss 0.2097
# Epoch 5 Loss 0.1759
# Time taken for 1 epoch 54.66698384284973 sec
#
# Epoch 6 Batch 0 Loss 0.1122
# Epoch 6 Batch 100 Loss 0.1375
# Epoch 6 Batch 200 Loss 0.0985
# Epoch 6 Batch 300 Loss 0.1147
# Epoch 6 Batch 400 Loss 0.1085
# Epoch 6 Batch 500 Loss 0.1380
# Epoch 6 Batch 600 Loss 0.1408
# Epoch 6 Batch 700 Loss 0.1445
# Epoch 6 Batch 800 Loss 0.1415
# Epoch 6 Batch 900 Loss 0.0926
# Epoch 6 Batch 1000 Loss 0.1407
# Epoch 6 Batch 1100 Loss 0.1336
# Epoch 6 Batch 1200 Loss 0.1369
# Epoch 6 Loss 0.1353
# Time taken for 1 epoch 56.051350593566895 sec
#
# Epoch 7 Batch 0 Loss 0.1067
# Epoch 7 Batch 100 Loss 0.1281
# Epoch 7 Batch 200 Loss 0.0932
# Epoch 7 Batch 300 Loss 0.0764
# Epoch 7 Batch 400 Loss 0.1154
# Epoch 7 Batch 500 Loss 0.1301
# Epoch 7 Batch 600 Loss 0.0880
# Epoch 7 Batch 700 Loss 0.1107
# Epoch 7 Batch 800 Loss 0.0884
# Epoch 7 Batch 900 Loss 0.1443
# Epoch 7 Batch 1000 Loss 0.1769
# Epoch 7 Batch 1100 Loss 0.1052
# Epoch 7 Batch 1200 Loss 0.1046
# Epoch 7 Loss 0.1155
# Time taken for 1 epoch 54.6272075176239 sec
#
# Epoch 8 Batch 0 Loss 0.1065
# Epoch 8 Batch 100 Loss 0.1030
# Epoch 8 Batch 200 Loss 0.0672
# Epoch 8 Batch 300 Loss 0.0936
# Epoch 8 Batch 400 Loss 0.0741
# Epoch 8 Batch 500 Loss 0.0940
# Epoch 8 Batch 600 Loss 0.1146
# Epoch 8 Batch 700 Loss 0.1324
# Epoch 8 Batch 800 Loss 0.1319
# Epoch 8 Batch 900 Loss 0.0821
# Epoch 8 Batch 1000 Loss 0.1397
# Epoch 8 Batch 1100 Loss 0.0977
# Epoch 8 Batch 1200 Loss 0.1311
# Epoch 8 Loss 0.1038
# Time taken for 1 epoch 56.49194526672363 sec
#
# Epoch 9 Batch 0 Loss 0.0885
# Epoch 9 Batch 100 Loss 0.0735
# Epoch 9 Batch 200 Loss 0.0762
# Epoch 9 Batch 300 Loss 0.1012
# Epoch 9 Batch 400 Loss 0.0712
# Epoch 9 Batch 500 Loss 0.1137
# Epoch 9 Batch 600 Loss 0.0594
# Epoch 9 Batch 700 Loss 0.0928
# Epoch 9 Batch 800 Loss 0.1513
# Epoch 9 Batch 900 Loss 0.1024
# Epoch 9 Batch 1000 Loss 0.1271
# Epoch 9 Batch 1100 Loss 0.1074
# Epoch 9 Batch 1200 Loss 0.1359
# Epoch 9 Loss 0.0959
# Time taken for 1 epoch 55.589500188827515 sec
#
# Epoch 10 Batch 0 Loss 0.0595
# Epoch 10 Batch 100 Loss 0.0583
# Epoch 10 Batch 200 Loss 0.0506
# Epoch 10 Batch 300 Loss 0.0604
# Epoch 10 Batch 400 Loss 0.1132
# Epoch 10 Batch 500 Loss 0.0952
# Epoch 10 Batch 600 Loss 0.1183
# Epoch 10 Batch 700 Loss 0.1018
# Epoch 10 Batch 800 Loss 0.1318
# Epoch 10 Batch 900 Loss 0.1009
# Epoch 10 Batch 1000 Loss 0.1414
# Epoch 10 Batch 1100 Loss 0.1170
# Epoch 10 Batch 1200 Loss 0.0770
# Epoch 10 Loss 0.0916
# Time taken for 1 epoch 56.52561807632446 sec
#
# Epoch 11 Batch 0 Loss 0.0724
# Epoch 11 Batch 100 Loss 0.0720
# Epoch 11 Batch 200 Loss 0.0667
# Epoch 11 Batch 300 Loss 0.1197
# Epoch 11 Batch 400 Loss 0.1113
# Epoch 11 Batch 500 Loss 0.0643
# Epoch 11 Batch 600 Loss 0.0610
# Epoch 11 Batch 700 Loss 0.1258
# Epoch 11 Batch 800 Loss 0.0971
# Epoch 11 Batch 900 Loss 0.1035
# Epoch 11 Batch 1000 Loss 0.1175
# Epoch 11 Batch 1100 Loss 0.1086
# Epoch 11 Batch 1200 Loss 0.1301
# Epoch 11 Loss 0.0881
# Time taken for 1 epoch 55.579508781433105 sec
#
# Epoch 12 Batch 0 Loss 0.0897
# Epoch 12 Batch 100 Loss 0.1017
# Epoch 12 Batch 200 Loss 0.0618
# Epoch 12 Batch 300 Loss 0.0584
# Epoch 12 Batch 400 Loss 0.0932
# Epoch 12 Batch 500 Loss 0.0705
# Epoch 12 Batch 600 Loss 0.0967
# Epoch 12 Batch 700 Loss 0.1079
# Epoch 12 Batch 800 Loss 0.0724
# Epoch 12 Batch 900 Loss 0.0505
# Epoch 12 Batch 1000 Loss 0.0841
# Epoch 12 Batch 1100 Loss 0.1342
# Epoch 12 Batch 1200 Loss 0.0807
# Epoch 12 Loss 0.0858
# Time taken for 1 epoch 56.44967794418335 sec
#
# Epoch 13 Batch 0 Loss 0.0663
# Epoch 13 Batch 100 Loss 0.0613
# Epoch 13 Batch 200 Loss 0.0685
# Epoch 13 Batch 300 Loss 0.0751
# Epoch 13 Batch 400 Loss 0.0746
# Epoch 13 Batch 500 Loss 0.0857
# Epoch 13 Batch 600 Loss 0.0917
# Epoch 13 Batch 700 Loss 0.0695
# Epoch 13 Batch 800 Loss 0.0637
# Epoch 13 Batch 900 Loss 0.0642
# Epoch 13 Batch 1000 Loss 0.1735
# Epoch 13 Batch 1100 Loss 0.1149
# Epoch 13 Batch 1200 Loss 0.1621
# Epoch 13 Loss 0.0821
# Time taken for 1 epoch 54.68770933151245 sec
#
# Epoch 14 Batch 0 Loss 0.0653
# Epoch 14 Batch 100 Loss 0.0436
# Epoch 14 Batch 200 Loss 0.0305
# Epoch 14 Batch 300 Loss 0.0348
# Epoch 14 Batch 400 Loss 0.0884
# Epoch 14 Batch 500 Loss 0.0569
# Epoch 14 Batch 600 Loss 0.1272
# Epoch 14 Batch 700 Loss 0.0677
# Epoch 14 Batch 800 Loss 0.0457
# Epoch 14 Batch 900 Loss 0.0816
# Epoch 14 Batch 1000 Loss 0.0829
# Epoch 14 Batch 1100 Loss 0.1316
# Epoch 14 Batch 1200 Loss 0.0542
# Epoch 14 Loss 0.0797
# Time taken for 1 epoch 55.50894284248352 sec
#
# Epoch 15 Batch 0 Loss 0.0771
# Epoch 15 Batch 100 Loss 0.0527
# Epoch 15 Batch 200 Loss 0.0734
# Epoch 15 Batch 300 Loss 0.0375
# Epoch 15 Batch 400 Loss 0.0447
# Epoch 15 Batch 500 Loss 0.1291
# Epoch 15 Batch 600 Loss 0.0876
# Epoch 15 Batch 700 Loss 0.1264
# Epoch 15 Batch 800 Loss 0.0510
# Epoch 15 Batch 900 Loss 0.1293
# Epoch 15 Batch 1000 Loss 0.1215
# Epoch 15 Batch 1100 Loss 0.1039
# Epoch 15 Batch 1200 Loss 0.1033
# Epoch 15 Loss 0.0799
# Time taken for 1 epoch 54.63723707199097 sec
#
# Epoch 16 Batch 0 Loss 0.0642
# Epoch 16 Batch 100 Loss 0.0418
# Epoch 16 Batch 200 Loss 0.0494
# Epoch 16 Batch 300 Loss 0.0580
# Epoch 16 Batch 400 Loss 0.0796
# Epoch 16 Batch 500 Loss 0.0974
# Epoch 16 Batch 600 Loss 0.0560
# Epoch 16 Batch 700 Loss 0.0830
# Epoch 16 Batch 800 Loss 0.0691
# Epoch 16 Batch 900 Loss 0.0657
# Epoch 16 Batch 1000 Loss 0.0871
# Epoch 16 Batch 1100 Loss 0.1026
# Epoch 16 Batch 1200 Loss 0.1220
# Epoch 16 Loss 0.0780
# Time taken for 1 epoch 56.3399338722229 sec
#
# Epoch 17 Batch 0 Loss 0.1078
# Epoch 17 Batch 100 Loss 0.0227
# Epoch 17 Batch 200 Loss 0.0525
# Epoch 17 Batch 300 Loss 0.0464
# Epoch 17 Batch 400 Loss 0.0566
# Epoch 17 Batch 500 Loss 0.0626
# Epoch 17 Batch 600 Loss 0.0608
# Epoch 17 Batch 700 Loss 0.1346
# Epoch 17 Batch 800 Loss 0.0932
# Epoch 17 Batch 900 Loss 0.0769
# Epoch 17 Batch 1000 Loss 0.0692
# Epoch 17 Batch 1100 Loss 0.0837
# Epoch 17 Batch 1200 Loss 0.1283
# Epoch 17 Loss 0.0746
# Time taken for 1 epoch 56.22343134880066 sec
#
# Epoch 18 Batch 0 Loss 0.0383
# Epoch 18 Batch 100 Loss 0.0578
# Epoch 18 Batch 200 Loss 0.0857
# Epoch 18 Batch 300 Loss 0.0326
# Epoch 18 Batch 400 Loss 0.1013
# Epoch 18 Batch 500 Loss 0.1022
# Epoch 18 Batch 600 Loss 0.0828
# Epoch 18 Batch 700 Loss 0.0943
# Epoch 18 Batch 800 Loss 0.1036
# Epoch 18 Batch 900 Loss 0.0697
# Epoch 18 Batch 1000 Loss 0.0765
# Epoch 18 Batch 1100 Loss 0.0673
# Epoch 18 Batch 1200 Loss 0.0909
# Epoch 18 Loss 0.0739
# Time taken for 1 epoch 56.97101306915283 sec
#
# Epoch 19 Batch 0 Loss 0.0975
# Epoch 19 Batch 100 Loss 0.0614
# Epoch 19 Batch 200 Loss 0.1292
# Epoch 19 Batch 300 Loss 0.0693
# Epoch 19 Batch 400 Loss 0.0862
# Epoch 19 Batch 500 Loss 0.0797
# Epoch 19 Batch 600 Loss 0.0523
# Epoch 19 Batch 700 Loss 0.0654
# Epoch 19 Batch 800 Loss 0.1073
# Epoch 19 Batch 900 Loss 0.0473
# Epoch 19 Batch 1000 Loss 0.0855
# Epoch 19 Batch 1100 Loss 0.0621
# Epoch 19 Batch 1200 Loss 0.0789
# Epoch 19 Loss 0.0732
# Time taken for 1 epoch 55.61997199058533 sec
#
# Epoch 20 Batch 0 Loss 0.0349
# Epoch 20 Batch 100 Loss 0.0487
# Epoch 20 Batch 200 Loss 0.0659
# Epoch 20 Batch 300 Loss 0.0712
# Epoch 20 Batch 400 Loss 0.0819
# Epoch 20 Batch 500 Loss 0.0665
# Epoch 20 Batch 600 Loss 0.0433
# Epoch 20 Batch 700 Loss 0.0545
# Epoch 20 Batch 800 Loss 0.0933
# Epoch 20 Batch 900 Loss 0.0761
# Epoch 20 Batch 1000 Loss 0.1093
# Epoch 20 Batch 1100 Loss 0.0588
# Epoch 20 Batch 1200 Loss 0.0867
# Epoch 20 Loss 0.0725
# Time taken for 1 epoch 56.57540202140808 sec
#
# Epoch 21 Batch 0 Loss 0.0816
# Epoch 21 Batch 100 Loss 0.0311
# Epoch 21 Batch 200 Loss 0.0386
# Epoch 21 Batch 300 Loss 0.0700
# Epoch 21 Batch 400 Loss 0.0969
# Epoch 21 Batch 500 Loss 0.0510
# Epoch 21 Batch 600 Loss 0.0583
# Epoch 21 Batch 700 Loss 0.0882
# Epoch 21 Batch 800 Loss 0.0724
# Epoch 21 Batch 900 Loss 0.1055
# Epoch 21 Batch 1000 Loss 0.0411
# Epoch 21 Batch 1100 Loss 0.0775
# Epoch 21 Batch 1200 Loss 0.1222
# Epoch 21 Loss 0.0705
# Time taken for 1 epoch 54.52047562599182 sec
#
# Epoch 22 Batch 0 Loss 0.0234
# Epoch 22 Batch 100 Loss 0.0854
# Epoch 22 Batch 200 Loss 0.0757
# Epoch 22 Batch 300 Loss 0.0472
# Epoch 22 Batch 400 Loss 0.0816
# Epoch 22 Batch 500 Loss 0.0795
# Epoch 22 Batch 600 Loss 0.1075
# Epoch 22 Batch 700 Loss 0.0588
# Epoch 22 Batch 800 Loss 0.0587
# Epoch 22 Batch 900 Loss 0.0703
# Epoch 22 Batch 1000 Loss 0.1049
# Epoch 22 Batch 1100 Loss 0.0992
# Epoch 22 Batch 1200 Loss 0.1120
# Epoch 22 Loss 0.0698
# Time taken for 1 epoch 56.18238162994385 sec
#
# Epoch 23 Batch 0 Loss 0.0213
# Epoch 23 Batch 100 Loss 0.0797
# Epoch 23 Batch 200 Loss 0.0487
# Epoch 23 Batch 300 Loss 0.0297
# Epoch 23 Batch 400 Loss 0.0213
# Epoch 23 Batch 500 Loss 0.0392
# Epoch 23 Batch 600 Loss 0.1168
# Epoch 23 Batch 700 Loss 0.0366
# Epoch 23 Batch 800 Loss 0.0908
# Epoch 23 Batch 900 Loss 0.0743
# Epoch 23 Batch 1000 Loss 0.0670
# Epoch 23 Batch 1100 Loss 0.1467
# Epoch 23 Batch 1200 Loss 0.1126
# Epoch 23 Loss 0.0684
# Time taken for 1 epoch 54.63264536857605 sec
#
# Epoch 24 Batch 0 Loss 0.0265
# Epoch 24 Batch 100 Loss 0.0354
# Epoch 24 Batch 200 Loss 0.0431
# Epoch 24 Batch 300 Loss 0.0564
# Epoch 24 Batch 400 Loss 0.0544
# Epoch 24 Batch 500 Loss 0.0538
# Epoch 24 Batch 600 Loss 0.0764
# Epoch 24 Batch 700 Loss 0.0610
# Epoch 24 Batch 800 Loss 0.0457
# Epoch 24 Batch 900 Loss 0.0757
# Epoch 24 Batch 1000 Loss 0.0804
# Epoch 24 Batch 1100 Loss 0.0506
# Epoch 24 Batch 1200 Loss 0.1270
# Epoch 24 Loss 0.0676
# Time taken for 1 epoch 56.70792245864868 sec
#
# Epoch 25 Batch 0 Loss 0.0700
# Epoch 25 Batch 100 Loss 0.0342
# Epoch 25 Batch 200 Loss 0.0487
# Epoch 25 Batch 300 Loss 0.1108
# Epoch 25 Batch 400 Loss 0.0427
# Epoch 25 Batch 500 Loss 0.1020
# Epoch 25 Batch 600 Loss 0.0693
# Epoch 25 Batch 700 Loss 0.0872
# Epoch 25 Batch 800 Loss 0.0669
# Epoch 25 Batch 900 Loss 0.0678
# Epoch 25 Batch 1000 Loss 0.0640
# Epoch 25 Batch 1100 Loss 0.0689
# Epoch 25 Batch 1200 Loss 0.0697
# Epoch 25 Loss 0.0669
# Time taken for 1 epoch 55.560521841049194 sec
#
# Epoch 26 Batch 0 Loss 0.0591
# Epoch 26 Batch 100 Loss 0.0623
# Epoch 26 Batch 200 Loss 0.0481
# Epoch 26 Batch 300 Loss 0.0359
# Epoch 26 Batch 400 Loss 0.0885
# Epoch 26 Batch 500 Loss 0.0496
# Epoch 26 Batch 600 Loss 0.0806
# Epoch 26 Batch 700 Loss 0.0439
# Epoch 26 Batch 800 Loss 0.0665
# Epoch 26 Batch 900 Loss 0.0972
# Epoch 26 Batch 1000 Loss 0.0522
# Epoch 26 Batch 1100 Loss 0.0967
# Epoch 26 Batch 1200 Loss 0.1189
# Epoch 26 Loss 0.0653
# Time taken for 1 epoch 55.88827085494995 sec
#
# Epoch 27 Batch 0 Loss 0.0519
# Epoch 27 Batch 100 Loss 0.0498
# Epoch 27 Batch 200 Loss 0.0185
# Epoch 27 Batch 300 Loss 0.0280
# Epoch 27 Batch 400 Loss 0.0632
# Epoch 27 Batch 500 Loss 0.0384
# Epoch 27 Batch 600 Loss 0.0330
# Epoch 27 Batch 700 Loss 0.0355
# Epoch 27 Batch 800 Loss 0.0699
# Epoch 27 Batch 900 Loss 0.0695
# Epoch 27 Batch 1000 Loss 0.1237
# Epoch 27 Batch 1100 Loss 0.0638
# Epoch 27 Batch 1200 Loss 0.0679
# Epoch 27 Loss 0.0644
# Time taken for 1 epoch 55.428598403930664 sec
#
# Epoch 28 Batch 0 Loss 0.0543
# Epoch 28 Batch 100 Loss 0.0314
# Epoch 28 Batch 200 Loss 0.0353
# Epoch 28 Batch 300 Loss 0.0694
# Epoch 28 Batch 400 Loss 0.0811
# Epoch 28 Batch 500 Loss 0.0400
# Epoch 28 Batch 600 Loss 0.0491
# Epoch 28 Batch 700 Loss 0.0575
# Epoch 28 Batch 800 Loss 0.1026
# Epoch 28 Batch 900 Loss 0.1056
# Epoch 28 Batch 1000 Loss 0.0579
# Epoch 28 Batch 1100 Loss 0.0947
# Epoch 28 Batch 1200 Loss 0.0650
# Epoch 28 Loss 0.0637
# Time taken for 1 epoch 56.689603328704834 sec
#
# Epoch 29 Batch 0 Loss 0.0610
# Epoch 29 Batch 100 Loss 0.0366
# Epoch 29 Batch 200 Loss 0.0182
# Epoch 29 Batch 300 Loss 0.0529
# Epoch 29 Batch 400 Loss 0.0611
# Epoch 29 Batch 500 Loss 0.0686
# Epoch 29 Batch 600 Loss 0.0349
# Epoch 29 Batch 700 Loss 0.0451
# Epoch 29 Batch 800 Loss 0.0713
# Epoch 29 Batch 900 Loss 0.0500
# Epoch 29 Batch 1000 Loss 0.0908
# Epoch 29 Batch 1100 Loss 0.0896
# Epoch 29 Batch 1200 Loss 0.0786
# Epoch 29 Loss 0.0635
# Time taken for 1 epoch 55.785465240478516 sec
#
# Epoch 30 Batch 0 Loss 0.0400
# Epoch 30 Batch 100 Loss 0.0593
# Epoch 30 Batch 200 Loss 0.0447
# Epoch 30 Batch 300 Loss 0.0369
# Epoch 30 Batch 400 Loss 0.0532
# Epoch 30 Batch 500 Loss 0.0765
# Epoch 30 Batch 600 Loss 0.0668
# Epoch 30 Batch 700 Loss 0.0477
# Epoch 30 Batch 800 Loss 0.0854
# Epoch 30 Batch 900 Loss 0.0824
# Epoch 30 Batch 1000 Loss 0.0582
# Epoch 30 Batch 1100 Loss 0.1020
# Epoch 30 Batch 1200 Loss 0.0784
# Epoch 30 Loss 0.0631
# Time taken for 1 epoch 56.36329984664917 sec
#
# Epoch 31 Batch 0 Loss 0.0462
# Epoch 31 Batch 100 Loss 0.0495
# Epoch 31 Batch 200 Loss 0.0425
# Epoch 31 Batch 300 Loss 0.0434
# Epoch 31 Batch 400 Loss 0.0806
# Epoch 31 Batch 500 Loss 0.0696
# Epoch 31 Batch 600 Loss 0.0298
# Epoch 31 Batch 700 Loss 0.0561
# Epoch 31 Batch 800 Loss 0.0728
# Epoch 31 Batch 900 Loss 0.0708
# Epoch 31 Batch 1000 Loss 0.0580
# Epoch 31 Batch 1100 Loss 0.0826
# Epoch 31 Batch 1200 Loss 0.0826
# Epoch 31 Loss 0.0614
# Time taken for 1 epoch 55.3866446018219 sec
#
# Epoch 32 Batch 0 Loss 0.0220
# Epoch 32 Batch 100 Loss 0.0586
# Epoch 32 Batch 200 Loss 0.1032
# Epoch 32 Batch 300 Loss 0.0499
# Epoch 32 Batch 400 Loss 0.0614
# Epoch 32 Batch 500 Loss 0.0499
# Epoch 32 Batch 600 Loss 0.0775
# Epoch 32 Batch 700 Loss 0.0620
# Epoch 32 Batch 800 Loss 0.0456
# Epoch 32 Batch 900 Loss 0.0576
# Epoch 32 Batch 1000 Loss 0.0641
# Epoch 32 Batch 1100 Loss 0.0681
# Epoch 32 Batch 1200 Loss 0.1552
# Epoch 32 Loss 0.0612
# Time taken for 1 epoch 57.2109100818634 sec
#
# Epoch 33 Batch 0 Loss 0.0839
# Epoch 33 Batch 100 Loss 0.0701
# Epoch 33 Batch 200 Loss 0.0517
# Epoch 33 Batch 300 Loss 0.0418
# Epoch 33 Batch 400 Loss 0.0413
# Epoch 33 Batch 500 Loss 0.0474
# Epoch 33 Batch 600 Loss 0.0582
# Epoch 33 Batch 700 Loss 0.0670
# Epoch 33 Batch 800 Loss 0.0461
# Epoch 33 Batch 900 Loss 0.0376
# Epoch 33 Batch 1000 Loss 0.0661
# Epoch 33 Batch 1100 Loss 0.0664
# Epoch 33 Batch 1200 Loss 0.0437
# Epoch 33 Loss 0.0607
# Time taken for 1 epoch 55.40042185783386 sec
#
# Epoch 34 Batch 0 Loss 0.0423
# Epoch 34 Batch 100 Loss 0.0533
# Epoch 34 Batch 200 Loss 0.0649
# Epoch 34 Batch 300 Loss 0.0731
# Epoch 34 Batch 400 Loss 0.0544
# Epoch 34 Batch 500 Loss 0.0625
# Epoch 34 Batch 600 Loss 0.0486
# Epoch 34 Batch 700 Loss 0.0653
# Epoch 34 Batch 800 Loss 0.0499
# Epoch 34 Batch 900 Loss 0.0386
# Epoch 34 Batch 1000 Loss 0.0479
# Epoch 34 Batch 1100 Loss 0.0893
# Epoch 34 Batch 1200 Loss 0.0820
# Epoch 34 Loss 0.0599
# Time taken for 1 epoch 55.610347509384155 sec
#
# Epoch 35 Batch 0 Loss 0.0504
# Epoch 35 Batch 100 Loss 0.0460
# Epoch 35 Batch 200 Loss 0.0623
# Epoch 35 Batch 300 Loss 0.0311
# Epoch 35 Batch 400 Loss 0.0394
# Epoch 35 Batch 500 Loss 0.0367
# Epoch 35 Batch 600 Loss 0.0647
# Epoch 35 Batch 700 Loss 0.0671
# Epoch 35 Batch 800 Loss 0.0574
# Epoch 35 Batch 900 Loss 0.0704
# Epoch 35 Batch 1000 Loss 0.0767
# Epoch 35 Batch 1100 Loss 0.0753
# Epoch 35 Batch 1200 Loss 0.0571
# Epoch 35 Loss 0.0590
# Time taken for 1 epoch 54.66933822631836 sec
#
# Epoch 36 Batch 0 Loss 0.0568
# Epoch 36 Batch 100 Loss 0.0290
# Epoch 36 Batch 200 Loss 0.0661
# Epoch 36 Batch 300 Loss 0.0806
# Epoch 36 Batch 400 Loss 0.0793
# Epoch 36 Batch 500 Loss 0.0667
# Epoch 36 Batch 600 Loss 0.0316
# Epoch 36 Batch 700 Loss 0.0862
# Epoch 36 Batch 800 Loss 0.0533
# Epoch 36 Batch 900 Loss 0.0533
# Epoch 36 Batch 1000 Loss 0.0800
# Epoch 36 Batch 1100 Loss 0.1096
# Epoch 36 Batch 1200 Loss 0.0538
# Epoch 36 Loss 0.0588
# Time taken for 1 epoch 55.65417265892029 sec
#
# Epoch 37 Batch 0 Loss 0.0467
# Epoch 37 Batch 100 Loss 0.0475
# Epoch 37 Batch 200 Loss 0.0387
# Epoch 37 Batch 300 Loss 0.0497
# Epoch 37 Batch 400 Loss 0.0462
# Epoch 37 Batch 500 Loss 0.0968
# Epoch 37 Batch 600 Loss 0.0257
# Epoch 37 Batch 700 Loss 0.0321
# Epoch 37 Batch 800 Loss 0.1102
# Epoch 37 Batch 900 Loss 0.0734
# Epoch 37 Batch 1000 Loss 0.0774
# Epoch 37 Batch 1100 Loss 0.1251
# Epoch 37 Batch 1200 Loss 0.0703
# Epoch 37 Loss 0.0577
# Time taken for 1 epoch 54.700223207473755 sec
#
# Epoch 38 Batch 0 Loss 0.0511
# Epoch 38 Batch 100 Loss 0.0399
# Epoch 38 Batch 200 Loss 0.0373
# Epoch 38 Batch 300 Loss 0.0360
# Epoch 38 Batch 400 Loss 0.0191
# Epoch 38 Batch 500 Loss 0.0568
# Epoch 38 Batch 600 Loss 0.0496
# Epoch 38 Batch 700 Loss 0.0355
# Epoch 38 Batch 800 Loss 0.0292
# Epoch 38 Batch 900 Loss 0.0715
# Epoch 38 Batch 1000 Loss 0.0556
# Epoch 38 Batch 1100 Loss 0.0633
# Epoch 38 Batch 1200 Loss 0.0655
# Epoch 38 Loss 0.0576
# Time taken for 1 epoch 55.801533460617065 sec
#
# Epoch 39 Batch 0 Loss 0.0521
# Epoch 39 Batch 100 Loss 0.0591
# Epoch 39 Batch 200 Loss 0.0490
# Epoch 39 Batch 300 Loss 0.0634
# Epoch 39 Batch 400 Loss 0.0250
# Epoch 39 Batch 500 Loss 0.0286
# Epoch 39 Batch 600 Loss 0.0257
# Epoch 39 Batch 700 Loss 0.0900
# Epoch 39 Batch 800 Loss 0.0805
# Epoch 39 Batch 900 Loss 0.0758
# Epoch 39 Batch 1000 Loss 0.0463
# Epoch 39 Batch 1100 Loss 0.0841
# Epoch 39 Batch 1200 Loss 0.0384
# Epoch 39 Loss 0.0566
# Time taken for 1 epoch 54.52392601966858 sec
#
# Epoch 40 Batch 0 Loss 0.0383
# Epoch 40 Batch 100 Loss 0.0317
# Epoch 40 Batch 200 Loss 0.0706
# Epoch 40 Batch 300 Loss 0.0717
# Epoch 40 Batch 400 Loss 0.0524
# Epoch 40 Batch 500 Loss 0.0614
# Epoch 40 Batch 600 Loss 0.0567
# Epoch 40 Batch 700 Loss 0.0747
# Epoch 40 Batch 800 Loss 0.0885
# Epoch 40 Batch 900 Loss 0.0570
# Epoch 40 Batch 1000 Loss 0.0361
# Epoch 40 Batch 1100 Loss 0.0448
# Epoch 40 Batch 1200 Loss 0.0692
# Epoch 40 Loss 0.0563
# Time taken for 1 epoch 56.02459216117859 sec
#
# Epoch 41 Batch 0 Loss 0.0384
# Epoch 41 Batch 100 Loss 0.0332
# Epoch 41 Batch 200 Loss 0.0669
# Epoch 41 Batch 300 Loss 0.0499
# Epoch 41 Batch 400 Loss 0.0501
# Epoch 41 Batch 500 Loss 0.0735
# Epoch 41 Batch 600 Loss 0.0609
# Epoch 41 Batch 700 Loss 0.0552
# Epoch 41 Batch 800 Loss 0.0611
# Epoch 41 Batch 900 Loss 0.0429
# Epoch 41 Batch 1000 Loss 0.0679
# Epoch 41 Batch 1100 Loss 0.0355
# Epoch 41 Batch 1200 Loss 0.0630
# Epoch 41 Loss 0.0559
# Time taken for 1 epoch 54.54567861557007 sec
#
# Epoch 42 Batch 0 Loss 0.0308
# Epoch 42 Batch 100 Loss 0.0236
# Epoch 42 Batch 200 Loss 0.0353
# Epoch 42 Batch 300 Loss 0.0353
# Epoch 42 Batch 400 Loss 0.0670
# Epoch 42 Batch 500 Loss 0.0419
# Epoch 42 Batch 600 Loss 0.0629
# Epoch 42 Batch 700 Loss 0.0930
# Epoch 42 Batch 800 Loss 0.0294
# Epoch 42 Batch 900 Loss 0.0495
# Epoch 42 Batch 1000 Loss 0.0690
# Epoch 42 Batch 1100 Loss 0.0442
# Epoch 42 Batch 1200 Loss 0.0555
# Epoch 42 Loss 0.0553
# Time taken for 1 epoch 55.57374382019043 sec
#
# Epoch 43 Batch 0 Loss 0.0403
# Epoch 43 Batch 100 Loss 0.0501
# Epoch 43 Batch 200 Loss 0.0181
# Epoch 43 Batch 300 Loss 0.0383
# Epoch 43 Batch 400 Loss 0.0851
# Epoch 43 Batch 500 Loss 0.0265
# Epoch 43 Batch 600 Loss 0.0511
# Epoch 43 Batch 700 Loss 0.0484
# Epoch 43 Batch 800 Loss 0.0833
# Epoch 43 Batch 900 Loss 0.0520
# Epoch 43 Batch 1000 Loss 0.0456
# Epoch 43 Batch 1100 Loss 0.0473
# Epoch 43 Batch 1200 Loss 0.0590
# Epoch 43 Loss 0.0554
# Time taken for 1 epoch 54.60203552246094 sec
#
# Epoch 44 Batch 0 Loss 0.0524
# Epoch 44 Batch 100 Loss 0.0390
# Epoch 44 Batch 200 Loss 0.0404
# Epoch 44 Batch 300 Loss 0.0560
# Epoch 44 Batch 400 Loss 0.0626
# Epoch 44 Batch 500 Loss 0.0860
# Epoch 44 Batch 600 Loss 0.0649
# Epoch 44 Batch 700 Loss 0.0810
# Epoch 44 Batch 800 Loss 0.0710
# Epoch 44 Batch 900 Loss 0.0627
# Epoch 44 Batch 1000 Loss 0.0734
# Epoch 44 Batch 1100 Loss 0.0534
# Epoch 44 Batch 1200 Loss 0.0850
# Epoch 44 Loss 0.0546
# Time taken for 1 epoch 56.09005665779114 sec
#
# Epoch 45 Batch 0 Loss 0.0318
# Epoch 45 Batch 100 Loss 0.0806
# Epoch 45 Batch 200 Loss 0.0344
# Epoch 45 Batch 300 Loss 0.0444
# Epoch 45 Batch 400 Loss 0.0426
# Epoch 45 Batch 500 Loss 0.0573
# Epoch 45 Batch 600 Loss 0.0425
# Epoch 45 Batch 700 Loss 0.0424
# Epoch 45 Batch 800 Loss 0.0281
# Epoch 45 Batch 900 Loss 0.0398
# Epoch 45 Batch 1000 Loss 0.0728
# Epoch 45 Batch 1100 Loss 0.0747
# Epoch 45 Batch 1200 Loss 0.0661
# Epoch 45 Loss 0.0539
# Time taken for 1 epoch 54.50919532775879 sec
#
# Epoch 46 Batch 0 Loss 0.0655
# Epoch 46 Batch 100 Loss 0.0315
# Epoch 46 Batch 200 Loss 0.0760
# Epoch 46 Batch 300 Loss 0.0255
# Epoch 46 Batch 400 Loss 0.0455
# Epoch 46 Batch 500 Loss 0.0463
# Epoch 46 Batch 600 Loss 0.0440
# Epoch 46 Batch 700 Loss 0.0559
# Epoch 46 Batch 800 Loss 0.0758
# Epoch 46 Batch 900 Loss 0.0590
# Epoch 46 Batch 1000 Loss 0.0499
# Epoch 46 Batch 1100 Loss 0.0229
# Epoch 46 Batch 1200 Loss 0.0833
# Epoch 46 Loss 0.0534
# Time taken for 1 epoch 55.61876583099365 sec
#
# Epoch 47 Batch 0 Loss 0.0386
# Epoch 47 Batch 100 Loss 0.0633
# Epoch 47 Batch 200 Loss 0.0880
# Epoch 47 Batch 300 Loss 0.0465
# Epoch 47 Batch 400 Loss 0.0614
# Epoch 47 Batch 500 Loss 0.0473
# Epoch 47 Batch 600 Loss 0.0748
# Epoch 47 Batch 700 Loss 0.0501
# Epoch 47 Batch 800 Loss 0.0509
# Epoch 47 Batch 900 Loss 0.0558
# Epoch 47 Batch 1000 Loss 0.0829
# Epoch 47 Batch 1100 Loss 0.0941
# Epoch 47 Batch 1200 Loss 0.0901
# Epoch 47 Loss 0.0531
# Time taken for 1 epoch 54.69030952453613 sec
#
# Epoch 48 Batch 0 Loss 0.0455
# Epoch 48 Batch 100 Loss 0.0244
# Epoch 48 Batch 200 Loss 0.0359
# Epoch 48 Batch 300 Loss 0.0548
# Epoch 48 Batch 400 Loss 0.0513
# Epoch 48 Batch 500 Loss 0.0794
# Epoch 48 Batch 600 Loss 0.0611
# Epoch 48 Batch 700 Loss 0.0704
# Epoch 48 Batch 800 Loss 0.0369
# Epoch 48 Batch 900 Loss 0.0488
# Epoch 48 Batch 1000 Loss 0.0489
# Epoch 48 Batch 1100 Loss 0.0625
# Epoch 48 Batch 1200 Loss 0.0436
# Epoch 48 Loss 0.0528
# Time taken for 1 epoch 56.22164177894592 sec
#
# Epoch 49 Batch 0 Loss 0.0328
# Epoch 49 Batch 100 Loss 0.0564
# Epoch 49 Batch 200 Loss 0.0272
# Epoch 49 Batch 300 Loss 0.0310
# Epoch 49 Batch 400 Loss 0.0567
# Epoch 49 Batch 500 Loss 0.0585
# Epoch 49 Batch 600 Loss 0.0430
# Epoch 49 Batch 700 Loss 0.0529
# Epoch 49 Batch 800 Loss 0.0477
# Epoch 49 Batch 900 Loss 0.0451
# Epoch 49 Batch 1000 Loss 0.0611
# Epoch 49 Batch 1100 Loss 0.0794
# Epoch 49 Batch 1200 Loss 0.0852
# Epoch 49 Loss 0.0523
# Time taken for 1 epoch 54.59343218803406 sec
#
# Epoch 50 Batch 0 Loss 0.0468
# Epoch 50 Batch 100 Loss 0.0426
# Epoch 50 Batch 200 Loss 0.0394
# Epoch 50 Batch 300 Loss 0.0437
# Epoch 50 Batch 400 Loss 0.0589
# Epoch 50 Batch 500 Loss 0.0418
# Epoch 50 Batch 600 Loss 0.0713
# Epoch 50 Batch 700 Loss 0.0428
# Epoch 50 Batch 800 Loss 0.0450
# Epoch 50 Batch 900 Loss 0.0728
# Epoch 50 Batch 1000 Loss 0.0386
# Epoch 50 Batch 1100 Loss 0.0882
# Epoch 50 Batch 1200 Loss 0.0624
# Epoch 50 Loss 0.0520
# Time taken for 1 epoch 56.09323239326477 sec

# %%
# Translate

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here . <end>

# %%
for sentense in ru[44000:44020]:
  #print(sentense[7:-5])
  translate(sentense[7:-5])
# Out:
# Input: <start> я ужинаю . <end>
# Predicted translation: i'm having dinner . <end>
# Input: <start> я здесь , чтобы научиться . <end>
# Predicted translation: i'm here to win . <end>
# Input: <start> я здесь с томом . <end>
# Predicted translation: i'm here with tom . <end>
# Input: <start> я надеюсь победить . <end>
# Predicted translation: i'm hoping to win . <end>
# Input: <start> я надеюсь выиграть . <end>
# Predicted translation: i expect to win . <end>
# Input: <start> я сейчас в бостоне . <end>
# Predicted translation: i'm now in boston . <end>
# Input: <start> я в плохом настроении . <end>
# Predicted translation: i'm in a bad mood . <end>
# Input: <start> у меня плохое настроение . <end>
# Predicted translation: i'm in a bad mood . <end>
# Input: <start> я в хорошей форме . <end>
# Predicted translation: i'm in good shape . <end>
# Input: <start> я в пижаме . <end>
# Predicted translation: i died such a wimp . <end>
# Input: <start> я сейчас в тюрьме . <end>
# Predicted translation: i'm now in jail . <end>
# Input: <start> я в подвале . <end>
# Predicted translation: i'm in the cellar . <end>
# Input: <start> я в погребе . <end>
# Predicted translation: i'm in the cellar . <end>
# Input: <start> я в саду . <end>
# Predicted translation: i am in the garden . <end>
# Input: <start> я в душе . <end>
# Predicted translation: i'm in the shower . <end>
# Input: <start> я в туалете . <end>
# Predicted translation: i'm in the toilet . <end>
# Input: <start> я в твоих руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я в ваших руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я в ваших руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я незаменим . <end>
# Predicted translation: i'm irreplaceable . <end>

# %%
# With Attention ############################

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 15, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    query_with_time_axis = tf.expand_dims(query, 1)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)
    ))
    attention_weights = tf.nn.softmax(score, axis=1)

    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 15, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    context_vector, attention_weights = self.attention(hidden, enc_output)

    x = self.embedding(x)

    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis = -1)

    output, state = self.gru(x)

    output = tf.reshape(output, (-1, output.shape[2]))

    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 7334)

# %%
# Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
checkpoint_dir = './training_attention_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.9649
# Epoch 1 Batch 100 Loss 2.2112
# Epoch 1 Batch 200 Loss 2.0651
# Epoch 1 Batch 300 Loss 1.9273
# Epoch 1 Batch 400 Loss 1.7460
# Epoch 1 Batch 500 Loss 1.6621
# Epoch 1 Batch 600 Loss 1.4266
# Epoch 1 Batch 700 Loss 1.4478
# Epoch 1 Batch 800 Loss 1.2365
# Epoch 1 Batch 900 Loss 1.2456
# Epoch 1 Batch 1000 Loss 1.0046
# Epoch 1 Batch 1100 Loss 1.1016
# Epoch 1 Batch 1200 Loss 0.9704
# Epoch 1 Loss 1.5905
# Time taken for 1 epoch 103.94581127166748 sec
#
# Epoch 2 Batch 0 Loss 0.8237
# Epoch 2 Batch 100 Loss 0.7238
# Epoch 2 Batch 200 Loss 0.6718
# Epoch 2 Batch 300 Loss 0.7733
# Epoch 2 Batch 400 Loss 0.6840
# Epoch 2 Batch 500 Loss 0.6277
# Epoch 2 Batch 600 Loss 0.6205
# Epoch 2 Batch 700 Loss 0.7033
# Epoch 2 Batch 800 Loss 0.5310
# Epoch 2 Batch 900 Loss 0.6188
# Epoch 2 Batch 1000 Loss 0.5612
# Epoch 2 Batch 1100 Loss 0.5011
# Epoch 2 Batch 1200 Loss 0.5392
# Epoch 2 Loss 0.6548
# Time taken for 1 epoch 93.68059539794922 sec
#
# Epoch 3 Batch 0 Loss 0.4554
# Epoch 3 Batch 100 Loss 0.2826
# Epoch 3 Batch 200 Loss 0.4140
# Epoch 3 Batch 300 Loss 0.3088
# Epoch 3 Batch 400 Loss 0.3167
# Epoch 3 Batch 500 Loss 0.3415
# Epoch 3 Batch 600 Loss 0.3786
# Epoch 3 Batch 700 Loss 0.2819
# Epoch 3 Batch 800 Loss 0.3751
# Epoch 3 Batch 900 Loss 0.3644
# Epoch 3 Batch 1000 Loss 0.3508
# Epoch 3 Batch 1100 Loss 0.2737
# Epoch 3 Batch 1200 Loss 0.3455
# Epoch 3 Loss 0.3451
# Time taken for 1 epoch 92.70935010910034 sec
#
# Epoch 4 Batch 0 Loss 0.1937
# Epoch 4 Batch 100 Loss 0.2085
# Epoch 4 Batch 200 Loss 0.2261
# Epoch 4 Batch 300 Loss 0.1503
# Epoch 4 Batch 400 Loss 0.1726
# Epoch 4 Batch 500 Loss 0.2416
# Epoch 4 Batch 600 Loss 0.2006
# Epoch 4 Batch 700 Loss 0.2237
# Epoch 4 Batch 800 Loss 0.2853
# Epoch 4 Batch 900 Loss 0.2156
# Epoch 4 Batch 1000 Loss 0.2994
# Epoch 4 Batch 1100 Loss 0.2375
# Epoch 4 Batch 1200 Loss 0.2767
# Epoch 4 Loss 0.2171
# Time taken for 1 epoch 93.35241794586182 sec
#
# Epoch 5 Batch 0 Loss 0.1200
# Epoch 5 Batch 100 Loss 0.1195
# Epoch 5 Batch 200 Loss 0.1491
# Epoch 5 Batch 300 Loss 0.1308
# Epoch 5 Batch 400 Loss 0.1358
# Epoch 5 Batch 500 Loss 0.1450
# Epoch 5 Batch 600 Loss 0.1528
# Epoch 5 Batch 700 Loss 0.1500
# Epoch 5 Batch 800 Loss 0.1908
# Epoch 5 Batch 900 Loss 0.1811
# Epoch 5 Batch 1000 Loss 0.1328
# Epoch 5 Batch 1100 Loss 0.1953
# Epoch 5 Batch 1200 Loss 0.1652
# Epoch 5 Loss 0.1569
# Time taken for 1 epoch 92.53688788414001 sec
#
# Epoch 6 Batch 0 Loss 0.0831
# Epoch 6 Batch 100 Loss 0.1024
# Epoch 6 Batch 200 Loss 0.0869
# Epoch 6 Batch 300 Loss 0.0809
# Epoch 6 Batch 400 Loss 0.1309
# Epoch 6 Batch 500 Loss 0.0880
# Epoch 6 Batch 600 Loss 0.1412
# Epoch 6 Batch 700 Loss 0.0865
# Epoch 6 Batch 800 Loss 0.1215
# Epoch 6 Batch 900 Loss 0.1480
# Epoch 6 Batch 1000 Loss 0.1760
# Epoch 6 Batch 1100 Loss 0.1327
# Epoch 6 Batch 1200 Loss 0.1423
# Epoch 6 Loss 0.1263
# Time taken for 1 epoch 93.5198118686676 sec
#
# Epoch 7 Batch 0 Loss 0.1006
# Epoch 7 Batch 100 Loss 0.1067
# Epoch 7 Batch 200 Loss 0.1325
# Epoch 7 Batch 300 Loss 0.0959
# Epoch 7 Batch 400 Loss 0.0946
# Epoch 7 Batch 500 Loss 0.1069
# Epoch 7 Batch 600 Loss 0.1209
# Epoch 7 Batch 700 Loss 0.1394
# Epoch 7 Batch 800 Loss 0.1102
# Epoch 7 Batch 900 Loss 0.1020
# Epoch 7 Batch 1000 Loss 0.0904
# Epoch 7 Batch 1100 Loss 0.0970
# Epoch 7 Batch 1200 Loss 0.1507
# Epoch 7 Loss 0.1072
# Time taken for 1 epoch 92.67069673538208 sec
#
# Epoch 8 Batch 0 Loss 0.0877
# Epoch 8 Batch 100 Loss 0.0607
# Epoch 8 Batch 200 Loss 0.0495
# Epoch 8 Batch 300 Loss 0.0788
# Epoch 8 Batch 400 Loss 0.0584
# Epoch 8 Batch 500 Loss 0.1154
# Epoch 8 Batch 600 Loss 0.1134
# Epoch 8 Batch 700 Loss 0.0992
# Epoch 8 Batch 800 Loss 0.1045
# Epoch 8 Batch 900 Loss 0.0708
# Epoch 8 Batch 1000 Loss 0.1310
# Epoch 8 Batch 1100 Loss 0.1039
# Epoch 8 Batch 1200 Loss 0.0805
# Epoch 8 Loss 0.0963
# Time taken for 1 epoch 93.44055581092834 sec
#
# Epoch 9 Batch 0 Loss 0.0759
# Epoch 9 Batch 100 Loss 0.0694
# Epoch 9 Batch 200 Loss 0.0481
# Epoch 9 Batch 300 Loss 0.0808
# Epoch 9 Batch 400 Loss 0.0597
# Epoch 9 Batch 500 Loss 0.0853
# Epoch 9 Batch 600 Loss 0.1195
# Epoch 9 Batch 700 Loss 0.0904
# Epoch 9 Batch 800 Loss 0.0588
# Epoch 9 Batch 900 Loss 0.1085
# Epoch 9 Batch 1000 Loss 0.0921
# Epoch 9 Batch 1100 Loss 0.1053
# Epoch 9 Batch 1200 Loss 0.0740
# Epoch 9 Loss 0.0883
# Time taken for 1 epoch 92.48947715759277 sec
#
# Epoch 10 Batch 0 Loss 0.0537
# Epoch 10 Batch 100 Loss 0.0797
# Epoch 10 Batch 200 Loss 0.1104
# Epoch 10 Batch 300 Loss 0.1022
# Epoch 10 Batch 400 Loss 0.0496
# Epoch 10 Batch 500 Loss 0.0712
# Epoch 10 Batch 600 Loss 0.0664
# Epoch 10 Batch 700 Loss 0.0813
# Epoch 10 Batch 800 Loss 0.0748
# Epoch 10 Batch 900 Loss 0.0668
# Epoch 10 Batch 1000 Loss 0.1001
# Epoch 10 Batch 1100 Loss 0.0668
# Epoch 10 Batch 1200 Loss 0.0940
# Epoch 10 Loss 0.0831
# Time taken for 1 epoch 93.17337012290955 sec
#
# Epoch 11 Batch 0 Loss 0.0855
# Epoch 11 Batch 100 Loss 0.0537
# Epoch 11 Batch 200 Loss 0.0867
# Epoch 11 Batch 300 Loss 0.0661
# Epoch 11 Batch 400 Loss 0.0952
# Epoch 11 Batch 500 Loss 0.1096
# Epoch 11 Batch 600 Loss 0.1066
# Epoch 11 Batch 700 Loss 0.0990
# Epoch 11 Batch 800 Loss 0.1057
# Epoch 11 Batch 900 Loss 0.1288
# Epoch 11 Batch 1000 Loss 0.0651
# Epoch 11 Batch 1100 Loss 0.0829
# Epoch 11 Batch 1200 Loss 0.0615
# Epoch 11 Loss 0.0789
# Time taken for 1 epoch 92.57051157951355 sec
#
# Epoch 12 Batch 0 Loss 0.0473
# Epoch 12 Batch 100 Loss 0.0297
# Epoch 12 Batch 200 Loss 0.0747
# Epoch 12 Batch 300 Loss 0.0611
# Epoch 12 Batch 400 Loss 0.0452
# Epoch 12 Batch 500 Loss 0.0798
# Epoch 12 Batch 600 Loss 0.0657
# Epoch 12 Batch 700 Loss 0.0451
# Epoch 12 Batch 800 Loss 0.0880
# Epoch 12 Batch 900 Loss 0.1103
# Epoch 12 Batch 1000 Loss 0.0700
# Epoch 12 Batch 1100 Loss 0.0728
# Epoch 12 Batch 1200 Loss 0.0605
# Epoch 12 Loss 0.0749
# Time taken for 1 epoch 93.4255645275116 sec
#
# Epoch 13 Batch 0 Loss 0.0573
# Epoch 13 Batch 100 Loss 0.0752
# Epoch 13 Batch 200 Loss 0.0586
# Epoch 13 Batch 300 Loss 0.0798
# Epoch 13 Batch 400 Loss 0.1041
# Epoch 13 Batch 500 Loss 0.0729
# Epoch 13 Batch 600 Loss 0.0596
# Epoch 13 Batch 700 Loss 0.1026
# Epoch 13 Batch 800 Loss 0.0533
# Epoch 13 Batch 900 Loss 0.0732
# Epoch 13 Batch 1000 Loss 0.0970
# Epoch 13 Batch 1100 Loss 0.0749
# Epoch 13 Batch 1200 Loss 0.0920
# Epoch 13 Loss 0.0711
# Time taken for 1 epoch 92.53637957572937 sec
#
# Epoch 14 Batch 0 Loss 0.0536
# Epoch 14 Batch 100 Loss 0.0491
# Epoch 14 Batch 200 Loss 0.0627
# Epoch 14 Batch 300 Loss 0.1125
# Epoch 14 Batch 400 Loss 0.0829
# Epoch 14 Batch 500 Loss 0.0494
# Epoch 14 Batch 600 Loss 0.1077
# Epoch 14 Batch 700 Loss 0.0449
# Epoch 14 Batch 800 Loss 0.0627
# Epoch 14 Batch 900 Loss 0.0568
# Epoch 14 Batch 1000 Loss 0.0412
# Epoch 14 Batch 1100 Loss 0.0507
# Epoch 14 Batch 1200 Loss 0.0940
# Epoch 14 Loss 0.0694
# Time taken for 1 epoch 93.23081755638123 sec
#
# Epoch 15 Batch 0 Loss 0.0790
# Epoch 15 Batch 100 Loss 0.0561
# Epoch 15 Batch 200 Loss 0.0600
# Epoch 15 Batch 300 Loss 0.0454
# Epoch 15 Batch 400 Loss 0.0488
# Epoch 15 Batch 500 Loss 0.0795
# Epoch 15 Batch 600 Loss 0.0637
# Epoch 15 Batch 700 Loss 0.0495
# Epoch 15 Batch 800 Loss 0.0483
# Epoch 15 Batch 900 Loss 0.0336
# Epoch 15 Batch 1000 Loss 0.1180
# Epoch 15 Batch 1100 Loss 0.1131
# Epoch 15 Batch 1200 Loss 0.0596
# Epoch 15 Loss 0.0656
# Time taken for 1 epoch 92.55441188812256 sec
#
# Epoch 16 Batch 0 Loss 0.0429
# Epoch 16 Batch 100 Loss 0.0409
# Epoch 16 Batch 200 Loss 0.0773
# Epoch 16 Batch 300 Loss 0.0348
# Epoch 16 Batch 400 Loss 0.0777
# Epoch 16 Batch 500 Loss 0.0467
# Epoch 16 Batch 600 Loss 0.0621
# Epoch 16 Batch 700 Loss 0.0518
# Epoch 16 Batch 800 Loss 0.1371
# Epoch 16 Batch 900 Loss 0.1027
# Epoch 16 Batch 1000 Loss 0.0708
# Epoch 16 Batch 1100 Loss 0.0580
# Epoch 16 Batch 1200 Loss 0.0910
# Epoch 16 Loss 0.0650
# Time taken for 1 epoch 93.3806540966034 sec
#
# Epoch 17 Batch 0 Loss 0.0242
# Epoch 17 Batch 100 Loss 0.0502
# Epoch 17 Batch 200 Loss 0.0558
# Epoch 17 Batch 300 Loss 0.0668
# Epoch 17 Batch 400 Loss 0.0565
# Epoch 17 Batch 500 Loss 0.0397
# Epoch 17 Batch 600 Loss 0.0468
# Epoch 17 Batch 700 Loss 0.0801
# Epoch 17 Batch 800 Loss 0.0490
# Epoch 17 Batch 900 Loss 0.0755
# Epoch 17 Batch 1000 Loss 0.0646
# Epoch 17 Batch 1100 Loss 0.0683
# Epoch 17 Batch 1200 Loss 0.0956
# Epoch 17 Loss 0.0635
# Time taken for 1 epoch 92.64233779907227 sec
#
# Epoch 18 Batch 0 Loss 0.0606
# Epoch 18 Batch 100 Loss 0.0703
# Epoch 18 Batch 200 Loss 0.0709
# Epoch 18 Batch 300 Loss 0.0589
# Epoch 18 Batch 400 Loss 0.0689
# Epoch 18 Batch 500 Loss 0.0539
# Epoch 18 Batch 600 Loss 0.0621
# Epoch 18 Batch 700 Loss 0.0446
# Epoch 18 Batch 800 Loss 0.0698
# Epoch 18 Batch 900 Loss 0.0628
# Epoch 18 Batch 1000 Loss 0.0467
# Epoch 18 Batch 1100 Loss 0.0765
# Epoch 18 Batch 1200 Loss 0.1024
# Epoch 18 Loss 0.0614
# Time taken for 1 epoch 93.36412072181702 sec
#
# Epoch 19 Batch 0 Loss 0.0590
# Epoch 19 Batch 100 Loss 0.0425
# Epoch 19 Batch 200 Loss 0.0333
# Epoch 19 Batch 300 Loss 0.0352
# Epoch 19 Batch 400 Loss 0.0720
# Epoch 19 Batch 500 Loss 0.0715
# Epoch 19 Batch 600 Loss 0.0431
# Epoch 19 Batch 700 Loss 0.0554
# Epoch 19 Batch 800 Loss 0.0812
# Epoch 19 Batch 900 Loss 0.0617
# Epoch 19 Batch 1000 Loss 0.0737
# Epoch 19 Batch 1100 Loss 0.0353
# Epoch 19 Batch 1200 Loss 0.0714
# Epoch 19 Loss 0.0605
# Time taken for 1 epoch 92.64431071281433 sec
#
# Epoch 20 Batch 0 Loss 0.0292
# Epoch 20 Batch 100 Loss 0.0404
# Epoch 20 Batch 200 Loss 0.0488
# Epoch 20 Batch 300 Loss 0.0685
# Epoch 20 Batch 400 Loss 0.0901
# Epoch 20 Batch 500 Loss 0.0463
# Epoch 20 Batch 600 Loss 0.0600
# Epoch 20 Batch 700 Loss 0.0427
# Epoch 20 Batch 800 Loss 0.0839
# Epoch 20 Batch 900 Loss 0.0752
# Epoch 20 Batch 1000 Loss 0.0506
# Epoch 20 Batch 1100 Loss 0.0796
# Epoch 20 Batch 1200 Loss 0.0320
# Epoch 20 Loss 0.0586
# Time taken for 1 epoch 93.44049572944641 sec
#
# Epoch 21 Batch 0 Loss 0.0354
# Epoch 21 Batch 100 Loss 0.0376
# Epoch 21 Batch 200 Loss 0.0446
# Epoch 21 Batch 300 Loss 0.0551
# Epoch 21 Batch 400 Loss 0.0555
# Epoch 21 Batch 500 Loss 0.0407
# Epoch 21 Batch 600 Loss 0.0500
# Epoch 21 Batch 700 Loss 0.0465
# Epoch 21 Batch 800 Loss 0.0436
# Epoch 21 Batch 900 Loss 0.0724
# Epoch 21 Batch 1000 Loss 0.0366
# Epoch 21 Batch 1100 Loss 0.1118
# Epoch 21 Batch 1200 Loss 0.0973
# Epoch 21 Loss 0.0575
# Time taken for 1 epoch 92.56758522987366 sec
#
# Epoch 22 Batch 0 Loss 0.0313
# Epoch 22 Batch 100 Loss 0.0580
# Epoch 22 Batch 200 Loss 0.0490
# Epoch 22 Batch 300 Loss 0.0389
# Epoch 22 Batch 400 Loss 0.0583
# Epoch 22 Batch 500 Loss 0.0797
# Epoch 22 Batch 600 Loss 0.0774
# Epoch 22 Batch 700 Loss 0.0682
# Epoch 22 Batch 800 Loss 0.0543
# Epoch 22 Batch 900 Loss 0.0279
# Epoch 22 Batch 1000 Loss 0.0656
# Epoch 22 Batch 1100 Loss 0.0586
# Epoch 22 Batch 1200 Loss 0.0707
# Epoch 22 Loss 0.0574
# Time taken for 1 epoch 93.37922477722168 sec
#
# Epoch 23 Batch 0 Loss 0.0343
# Epoch 23 Batch 100 Loss 0.0246
# Epoch 23 Batch 200 Loss 0.0159
# Epoch 23 Batch 300 Loss 0.0488
# Epoch 23 Batch 400 Loss 0.0371
# Epoch 23 Batch 500 Loss 0.0384
# Epoch 23 Batch 600 Loss 0.0358
# Epoch 23 Batch 700 Loss 0.0549
# Epoch 23 Batch 800 Loss 0.0453
# Epoch 23 Batch 900 Loss 0.0842
# Epoch 23 Batch 1000 Loss 0.0599
# Epoch 23 Batch 1100 Loss 0.0712
# Epoch 23 Batch 1200 Loss 0.0587
# Epoch 23 Loss 0.0549
# Time taken for 1 epoch 92.5099732875824 sec
#
# Epoch 24 Batch 0 Loss 0.0553
# Epoch 24 Batch 100 Loss 0.0565
# Epoch 24 Batch 200 Loss 0.0383
# Epoch 24 Batch 300 Loss 0.0516
# Epoch 24 Batch 400 Loss 0.0866
# Epoch 24 Batch 500 Loss 0.0417
# Epoch 24 Batch 600 Loss 0.0754
# Epoch 24 Batch 700 Loss 0.0563
# Epoch 24 Batch 800 Loss 0.0571
# Epoch 24 Batch 900 Loss 0.0653
# Epoch 24 Batch 1000 Loss 0.0720
# Epoch 24 Batch 1100 Loss 0.0527
# Epoch 24 Batch 1200 Loss 0.0585
# Epoch 24 Loss 0.0553
# Time taken for 1 epoch 93.20338797569275 sec
#
# Epoch 25 Batch 0 Loss 0.0504
# Epoch 25 Batch 100 Loss 0.0346
# Epoch 25 Batch 200 Loss 0.0571
# Epoch 25 Batch 300 Loss 0.0513
# Epoch 25 Batch 400 Loss 0.0741
# Epoch 25 Batch 500 Loss 0.0578
# Epoch 25 Batch 600 Loss 0.0699
# Epoch 25 Batch 700 Loss 0.0425
# Epoch 25 Batch 800 Loss 0.0420
# Epoch 25 Batch 900 Loss 0.0588
# Epoch 25 Batch 1000 Loss 0.0483
# Epoch 25 Batch 1100 Loss 0.0502
# Epoch 25 Batch 1200 Loss 0.0973
# Epoch 25 Loss 0.0533
# Time taken for 1 epoch 92.44100308418274 sec
#
# Epoch 26 Batch 0 Loss 0.0516
# Epoch 26 Batch 100 Loss 0.0617
# Epoch 26 Batch 200 Loss 0.0444
# Epoch 26 Batch 300 Loss 0.0446
# Epoch 26 Batch 400 Loss 0.0592
# Epoch 26 Batch 500 Loss 0.0301
# Epoch 26 Batch 600 Loss 0.0498
# Epoch 26 Batch 700 Loss 0.0653
# Epoch 26 Batch 800 Loss 0.0532
# Epoch 26 Batch 900 Loss 0.0685
# Epoch 26 Batch 1000 Loss 0.0763
# Epoch 26 Batch 1100 Loss 0.0518
# Epoch 26 Batch 1200 Loss 0.0667
# Epoch 26 Loss 0.0526
# Time taken for 1 epoch 93.28956007957458 sec
#
# Epoch 27 Batch 0 Loss 0.0267
# Epoch 27 Batch 100 Loss 0.0262
# Epoch 27 Batch 200 Loss 0.0902
# Epoch 27 Batch 300 Loss 0.0469
# Epoch 27 Batch 400 Loss 0.0392
# Epoch 27 Batch 500 Loss 0.0565
# Epoch 27 Batch 600 Loss 0.0765
# Epoch 27 Batch 700 Loss 0.0869
# Epoch 27 Batch 800 Loss 0.0486
# Epoch 27 Batch 900 Loss 0.0620
# Epoch 27 Batch 1000 Loss 0.0765
# Epoch 27 Batch 1100 Loss 0.0624
# Epoch 27 Batch 1200 Loss 0.0735
# Epoch 27 Loss 0.0518
# Time taken for 1 epoch 92.49693989753723 sec
#
# Epoch 28 Batch 0 Loss 0.0414
# Epoch 28 Batch 100 Loss 0.0591
# Epoch 28 Batch 200 Loss 0.0298
# Epoch 28 Batch 300 Loss 0.0445
# Epoch 28 Batch 400 Loss 0.0549
# Epoch 28 Batch 500 Loss 0.0445
# Epoch 28 Batch 600 Loss 0.0460
# Epoch 28 Batch 700 Loss 0.0262
# Epoch 28 Batch 800 Loss 0.0586
# Epoch 28 Batch 900 Loss 0.0575
# Epoch 28 Batch 1000 Loss 0.0525
# Epoch 28 Batch 1100 Loss 0.0641
# Epoch 28 Batch 1200 Loss 0.0664
# Epoch 28 Loss 0.0514
# Time taken for 1 epoch 93.06469464302063 sec
#
# Epoch 29 Batch 0 Loss 0.0399
# Epoch 29 Batch 100 Loss 0.0502
# Epoch 29 Batch 200 Loss 0.0331
# Epoch 29 Batch 300 Loss 0.0259
# Epoch 29 Batch 400 Loss 0.0477
# Epoch 29 Batch 500 Loss 0.0408
# Epoch 29 Batch 600 Loss 0.0444
# Epoch 29 Batch 700 Loss 0.0680
# Epoch 29 Batch 800 Loss 0.0339
# Epoch 29 Batch 900 Loss 0.0675
# Epoch 29 Batch 1000 Loss 0.0485
# Epoch 29 Batch 1100 Loss 0.0284
# Epoch 29 Batch 1200 Loss 0.0573
# Epoch 29 Loss 0.0505
# Time taken for 1 epoch 92.39901614189148 sec
#
# Epoch 30 Batch 0 Loss 0.0558
# Epoch 30 Batch 100 Loss 0.0370
# Epoch 30 Batch 200 Loss 0.0475
# Epoch 30 Batch 300 Loss 0.0281
# Epoch 30 Batch 400 Loss 0.0358
# Epoch 30 Batch 500 Loss 0.0284
# Epoch 30 Batch 600 Loss 0.0385
# Epoch 30 Batch 700 Loss 0.0684
# Epoch 30 Batch 800 Loss 0.0462
# Epoch 30 Batch 900 Loss 0.0716
# Epoch 30 Batch 1000 Loss 0.0453
# Epoch 30 Batch 1100 Loss 0.0645
# Epoch 30 Batch 1200 Loss 0.0508
# Epoch 30 Loss 0.0501
# Time taken for 1 epoch 93.30376744270325 sec
#
# Epoch 31 Batch 0 Loss 0.0464
# Epoch 31 Batch 100 Loss 0.0383
# Epoch 31 Batch 200 Loss 0.0275
# Epoch 31 Batch 300 Loss 0.0338
# Epoch 31 Batch 400 Loss 0.0386
# Epoch 31 Batch 500 Loss 0.0468
# Epoch 31 Batch 600 Loss 0.0452
# Epoch 31 Batch 700 Loss 0.0462
# Epoch 31 Batch 800 Loss 0.0250
# Epoch 31 Batch 900 Loss 0.0477
# Epoch 31 Batch 1000 Loss 0.0504
# Epoch 31 Batch 1100 Loss 0.0576
# Epoch 31 Batch 1200 Loss 0.0409
# Epoch 31 Loss 0.0488
# Time taken for 1 epoch 92.51860022544861 sec
#
# Epoch 32 Batch 0 Loss 0.0294
# Epoch 32 Batch 100 Loss 0.0541
# Epoch 32 Batch 200 Loss 0.0600
# Epoch 32 Batch 300 Loss 0.0396
# Epoch 32 Batch 400 Loss 0.0552
# Epoch 32 Batch 500 Loss 0.0380
# Epoch 32 Batch 600 Loss 0.0562
# Epoch 32 Batch 700 Loss 0.0560
# Epoch 32 Batch 800 Loss 0.0301
# Epoch 32 Batch 900 Loss 0.0218
# Epoch 32 Batch 1000 Loss 0.0744
# Epoch 32 Batch 1100 Loss 0.0459
# Epoch 32 Batch 1200 Loss 0.0641
# Epoch 32 Loss 0.0480
# Time taken for 1 epoch 93.31850481033325 sec
#
# Epoch 33 Batch 0 Loss 0.0244
# Epoch 33 Batch 100 Loss 0.0316
# Epoch 33 Batch 200 Loss 0.0271
# Epoch 33 Batch 300 Loss 0.0656
# Epoch 33 Batch 400 Loss 0.0499
# Epoch 33 Batch 500 Loss 0.0565
# Epoch 33 Batch 600 Loss 0.0649
# Epoch 33 Batch 700 Loss 0.0434
# Epoch 33 Batch 800 Loss 0.0322
# Epoch 33 Batch 900 Loss 0.0278
# Epoch 33 Batch 1000 Loss 0.0746
# Epoch 33 Batch 1100 Loss 0.0384
# Epoch 33 Batch 1200 Loss 0.0637
# Epoch 33 Loss 0.0482
# Time taken for 1 epoch 92.51649117469788 sec
#
# Epoch 34 Batch 0 Loss 0.0365
# Epoch 34 Batch 100 Loss 0.0318
# Epoch 34 Batch 200 Loss 0.0311
# Epoch 34 Batch 300 Loss 0.0403
# Epoch 34 Batch 400 Loss 0.0532
# Epoch 34 Batch 500 Loss 0.0486
# Epoch 34 Batch 600 Loss 0.0398
# Epoch 34 Batch 700 Loss 0.0422
# Epoch 34 Batch 800 Loss 0.0520
# Epoch 34 Batch 900 Loss 0.0749
# Epoch 34 Batch 1000 Loss 0.0566
# Epoch 34 Batch 1100 Loss 0.0613
# Epoch 34 Batch 1200 Loss 0.0642
# Epoch 34 Loss 0.0486
# Time taken for 1 epoch 93.44097018241882 sec
#
# Epoch 35 Batch 0 Loss 0.0282
# Epoch 35 Batch 100 Loss 0.0376
# Epoch 35 Batch 200 Loss 0.0412
# Epoch 35 Batch 300 Loss 0.0472
# Epoch 35 Batch 400 Loss 0.0290
# Epoch 35 Batch 500 Loss 0.0533
# Epoch 35 Batch 600 Loss 0.0560
# Epoch 35 Batch 700 Loss 0.0512
# Epoch 35 Batch 800 Loss 0.0341
# Epoch 35 Batch 900 Loss 0.0458
# Epoch 35 Batch 1000 Loss 0.0452
# Epoch 35 Batch 1100 Loss 0.0510
# Epoch 35 Batch 1200 Loss 0.0591
# Epoch 35 Loss 0.0464
# Time taken for 1 epoch 92.44306349754333 sec
#
# Epoch 36 Batch 0 Loss 0.0353
# Epoch 36 Batch 100 Loss 0.0615
# Epoch 36 Batch 200 Loss 0.0355
# Epoch 36 Batch 300 Loss 0.0139
# Epoch 36 Batch 400 Loss 0.0512
# Epoch 36 Batch 500 Loss 0.0605
# Epoch 36 Batch 600 Loss 0.0394
# Epoch 36 Batch 700 Loss 0.0498
# Epoch 36 Batch 800 Loss 0.0449
# Epoch 36 Batch 900 Loss 0.0649
# Epoch 36 Batch 1000 Loss 0.0382
# Epoch 36 Batch 1100 Loss 0.0205
# Epoch 36 Batch 1200 Loss 0.0441
# Epoch 36 Loss 0.0458
# Time taken for 1 epoch 93.39390015602112 sec
#
# Epoch 37 Batch 0 Loss 0.0230
# Epoch 37 Batch 100 Loss 0.0491
# Epoch 37 Batch 200 Loss 0.0266
# Epoch 37 Batch 300 Loss 0.0255
# Epoch 37 Batch 400 Loss 0.0566
# Epoch 37 Batch 500 Loss 0.0335
# Epoch 37 Batch 600 Loss 0.0347
# Epoch 37 Batch 700 Loss 0.0386
# Epoch 37 Batch 800 Loss 0.0481
# Epoch 37 Batch 900 Loss 0.0726
# Epoch 37 Batch 1000 Loss 0.0381
# Epoch 37 Batch 1100 Loss 0.0442
# Epoch 37 Batch 1200 Loss 0.0547
# Epoch 37 Loss 0.0459
# Time taken for 1 epoch 92.42029476165771 sec
#
# Epoch 38 Batch 0 Loss 0.0335
# Epoch 38 Batch 100 Loss 0.0137
# Epoch 38 Batch 200 Loss 0.0740
# Epoch 38 Batch 300 Loss 0.0611
# Epoch 38 Batch 400 Loss 0.0682
# Epoch 38 Batch 500 Loss 0.0425
# Epoch 38 Batch 600 Loss 0.0605
# Epoch 38 Batch 700 Loss 0.0420
# Epoch 38 Batch 800 Loss 0.0470
# Epoch 38 Batch 900 Loss 0.0561
# Epoch 38 Batch 1000 Loss 0.0454
# Epoch 38 Batch 1100 Loss 0.0788
# Epoch 38 Batch 1200 Loss 0.0357
# Epoch 38 Loss 0.0451
# Time taken for 1 epoch 93.10172033309937 sec
#
# Epoch 39 Batch 0 Loss 0.0294
# Epoch 39 Batch 100 Loss 0.0245
# Epoch 39 Batch 200 Loss 0.0158
# Epoch 39 Batch 300 Loss 0.0315
# Epoch 39 Batch 400 Loss 0.0289
# Epoch 39 Batch 500 Loss 0.0576
# Epoch 39 Batch 600 Loss 0.0387
# Epoch 39 Batch 700 Loss 0.0263
# Epoch 39 Batch 800 Loss 0.0478
# Epoch 39 Batch 900 Loss 0.0494
# Epoch 39 Batch 1000 Loss 0.0462
# Epoch 39 Batch 1100 Loss 0.0400
# Epoch 39 Batch 1200 Loss 0.0353
# Epoch 39 Loss 0.0453
# Time taken for 1 epoch 92.47968983650208 sec
#
# Epoch 40 Batch 0 Loss 0.0152
# Epoch 40 Batch 100 Loss 0.0395
# Epoch 40 Batch 200 Loss 0.0551
# Epoch 40 Batch 300 Loss 0.0530
# Epoch 40 Batch 400 Loss 0.0471
# Epoch 40 Batch 500 Loss 0.0761
# Epoch 40 Batch 600 Loss 0.0292
# Epoch 40 Batch 700 Loss 0.0819
# Epoch 40 Batch 800 Loss 0.0295
# Epoch 40 Batch 900 Loss 0.0605
# Epoch 40 Batch 1000 Loss 0.0558
# Epoch 40 Batch 1100 Loss 0.0612
# Epoch 40 Batch 1200 Loss 0.0500
# Epoch 40 Loss 0.0454
# Time taken for 1 epoch 93.37723517417908 sec
#
# Epoch 41 Batch 0 Loss 0.0264
# Epoch 41 Batch 100 Loss 0.0375
# Epoch 41 Batch 200 Loss 0.0849
# Epoch 41 Batch 300 Loss 0.0391
# Epoch 41 Batch 400 Loss 0.0453
# Epoch 41 Batch 500 Loss 0.0442
# Epoch 41 Batch 600 Loss 0.0468
# Epoch 41 Batch 700 Loss 0.0217
# Epoch 41 Batch 800 Loss 0.0571
# Epoch 41 Batch 900 Loss 0.0319
# Epoch 41 Batch 1000 Loss 0.0346
# Epoch 41 Batch 1100 Loss 0.0804
# Epoch 41 Batch 1200 Loss 0.0475
# Epoch 41 Loss 0.0462
# Time taken for 1 epoch 92.48367810249329 sec
#
# Epoch 42 Batch 0 Loss 0.0251
# Epoch 42 Batch 100 Loss 0.0219
# Epoch 42 Batch 200 Loss 0.0291
# Epoch 42 Batch 300 Loss 0.0483
# Epoch 42 Batch 400 Loss 0.0381
# Epoch 42 Batch 500 Loss 0.0635
# Epoch 42 Batch 600 Loss 0.0470
# Epoch 42 Batch 700 Loss 0.0559
# Epoch 42 Batch 800 Loss 0.0637
# Epoch 42 Batch 900 Loss 0.0216
# Epoch 42 Batch 1000 Loss 0.0564
# Epoch 42 Batch 1100 Loss 0.0270
# Epoch 42 Batch 1200 Loss 0.0331
# Epoch 42 Loss 0.0439
# Time taken for 1 epoch 93.27320837974548 sec
#
# Epoch 43 Batch 0 Loss 0.0305
# Epoch 43 Batch 100 Loss 0.0372
# Epoch 43 Batch 200 Loss 0.0407
# Epoch 43 Batch 300 Loss 0.0449
# Epoch 43 Batch 400 Loss 0.0306
# Epoch 43 Batch 500 Loss 0.0457
# Epoch 43 Batch 600 Loss 0.0798
# Epoch 43 Batch 700 Loss 0.0326
# Epoch 43 Batch 800 Loss 0.0236
# Epoch 43 Batch 900 Loss 0.0566
# Epoch 43 Batch 1000 Loss 0.0780
# Epoch 43 Batch 1100 Loss 0.0370
# Epoch 43 Batch 1200 Loss 0.0684
# Epoch 43 Loss 0.0434
# Time taken for 1 epoch 92.45545220375061 sec
#
# Epoch 44 Batch 0 Loss 0.0270
# Epoch 44 Batch 100 Loss 0.0336
# Epoch 44 Batch 200 Loss 0.0537
# Epoch 44 Batch 300 Loss 0.0475
# Epoch 44 Batch 400 Loss 0.0414
# Epoch 44 Batch 500 Loss 0.0603
# Epoch 44 Batch 600 Loss 0.0399
# Epoch 44 Batch 700 Loss 0.0553
# Epoch 44 Batch 800 Loss 0.0426
# Epoch 44 Batch 900 Loss 0.0472
# Epoch 44 Batch 1000 Loss 0.0703
# Epoch 44 Batch 1100 Loss 0.0541
# Epoch 44 Batch 1200 Loss 0.0565
# Epoch 44 Loss 0.0433
# Time taken for 1 epoch 93.24612188339233 sec
#
# Epoch 45 Batch 0 Loss 0.0293
# Epoch 45 Batch 100 Loss 0.0307
# Epoch 45 Batch 200 Loss 0.0254
# Epoch 45 Batch 300 Loss 0.0310
# Epoch 45 Batch 400 Loss 0.0318
# Epoch 45 Batch 500 Loss 0.0514
# Epoch 45 Batch 600 Loss 0.0513
# Epoch 45 Batch 700 Loss 0.0325
# Epoch 45 Batch 800 Loss 0.0294
# Epoch 45 Batch 900 Loss 0.0315
# Epoch 45 Batch 1000 Loss 0.0444
# Epoch 45 Batch 1100 Loss 0.0449
# Epoch 45 Batch 1200 Loss 0.0504
# Epoch 45 Loss 0.0430
# Time taken for 1 epoch 92.55305504798889 sec
#
# Epoch 46 Batch 0 Loss 0.0335
# Epoch 46 Batch 100 Loss 0.0380
# Epoch 46 Batch 200 Loss 0.0330
# Epoch 46 Batch 300 Loss 0.0444
# Epoch 46 Batch 400 Loss 0.0321
# Epoch 46 Batch 500 Loss 0.0644
# Epoch 46 Batch 600 Loss 0.0214
# Epoch 46 Batch 700 Loss 0.0403
# Epoch 46 Batch 800 Loss 0.0276
# Epoch 46 Batch 900 Loss 0.0582
# Epoch 46 Batch 1000 Loss 0.0818
# Epoch 46 Batch 1100 Loss 0.0405
# Epoch 46 Batch 1200 Loss 0.0499
# Epoch 46 Loss 0.0436
# Time taken for 1 epoch 93.04468584060669 sec
#
# Epoch 47 Batch 0 Loss 0.0151
# Epoch 47 Batch 100 Loss 0.0393
# Epoch 47 Batch 200 Loss 0.0409
# Epoch 47 Batch 300 Loss 0.0322
# Epoch 47 Batch 400 Loss 0.0390
# Epoch 47 Batch 500 Loss 0.0415
# Epoch 47 Batch 600 Loss 0.0241
# Epoch 47 Batch 700 Loss 0.0423
# Epoch 47 Batch 800 Loss 0.0690
# Epoch 47 Batch 900 Loss 0.0454
# Epoch 47 Batch 1000 Loss 0.0553
# Epoch 47 Batch 1100 Loss 0.0500
# Epoch 47 Batch 1200 Loss 0.0385
# Epoch 47 Loss 0.0434
# Time taken for 1 epoch 92.47351050376892 sec
#
# Epoch 48 Batch 0 Loss 0.0273
# Epoch 48 Batch 100 Loss 0.0370
# Epoch 48 Batch 200 Loss 0.0314
# Epoch 48 Batch 300 Loss 0.0423
# Epoch 48 Batch 400 Loss 0.0336
# Epoch 48 Batch 500 Loss 0.0364
# Epoch 48 Batch 600 Loss 0.0356
# Epoch 48 Batch 700 Loss 0.0358
# Epoch 48 Batch 800 Loss 0.0528
# Epoch 48 Batch 900 Loss 0.0327
# Epoch 48 Batch 1000 Loss 0.0415
# Epoch 48 Batch 1100 Loss 0.0386
# Epoch 48 Batch 1200 Loss 0.0483
# Epoch 48 Loss 0.0423
# Time taken for 1 epoch 93.29521942138672 sec
#
# Epoch 49 Batch 0 Loss 0.0306
# Epoch 49 Batch 100 Loss 0.0290
# Epoch 49 Batch 200 Loss 0.0250
# Epoch 49 Batch 300 Loss 0.0433
# Epoch 49 Batch 400 Loss 0.0445
# Epoch 49 Batch 500 Loss 0.0424
# Epoch 49 Batch 600 Loss 0.0741
# Epoch 49 Batch 700 Loss 0.0545
# Epoch 49 Batch 800 Loss 0.0524
# Epoch 49 Batch 900 Loss 0.0500
# Epoch 49 Batch 1000 Loss 0.0674
# Epoch 49 Batch 1100 Loss 0.0599
# Epoch 49 Batch 1200 Loss 0.0417
# Epoch 49 Loss 0.0415
# Time taken for 1 epoch 92.43139028549194 sec
#
# Epoch 50 Batch 0 Loss 0.0289
# Epoch 50 Batch 100 Loss 0.0350
# Epoch 50 Batch 200 Loss 0.0233
# Epoch 50 Batch 300 Loss 0.0461
# Epoch 50 Batch 400 Loss 0.0808
# Epoch 50 Batch 500 Loss 0.0394
# Epoch 50 Batch 600 Loss 0.0543
# Epoch 50 Batch 700 Loss 0.0280
# Epoch 50 Batch 800 Loss 0.0402
# Epoch 50 Batch 900 Loss 0.0453
# Epoch 50 Batch 1000 Loss 0.0557
# Epoch 50 Batch 1100 Loss 0.0527
# Epoch 50 Batch 1200 Loss 0.0632
# Epoch 50 Loss 0.0408
# Time taken for 1 epoch 93.37462496757507 sec

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
def translate_plot(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
translate_plot('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here . <end>

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  #attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  #plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
for sentense in ru[44000:44020]:
  translate(sentense[7:-5])
# Out:
# Input: <start> я ужинаю . <end>
# Predicted translation: i'm having dinner . <end>
# Input: <start> я здесь , чтобы научиться . <end>
# Predicted translation: i'm here to do . <end>
# Input: <start> я здесь с томом . <end>
# Predicted translation: i'm here with tom . <end>
# Input: <start> я надеюсь победить . <end>
# Predicted translation: i expect to win . <end>
# Input: <start> я надеюсь выиграть . <end>
# Predicted translation: i expect to win . <end>
# Input: <start> я сейчас в бостоне . <end>
# Predicted translation: i'm in boston now . <end>
# Input: <start> я в плохом настроении . <end>
# Predicted translation: i'm in a bad mood . <end>
# Input: <start> у меня плохое настроение . <end>
# Predicted translation: i'm in a bad mood . <end>
# Input: <start> я в хорошей форме . <end>
# Predicted translation: i'm in good shape . <end>
# Input: <start> я в пижаме . <end>
# Predicted translation: i'm in my pajamas . <end>
# Input: <start> я сейчас в тюрьме . <end>
# Predicted translation: i'm in jail now . <end>
# Input: <start> я в подвале . <end>
# Predicted translation: i'm in the cellar . <end>
# Input: <start> я в погребе . <end>
# Predicted translation: i'm in the cellar . <end>
# Input: <start> я в саду . <end>
# Predicted translation: i am in the garden . <end>
# Input: <start> я в душе . <end>
# Predicted translation: i'm in the shower . <end>
# Input: <start> я в туалете . <end>
# Predicted translation: i'm in the toilet . <end>
# Input: <start> я в твоих руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я в ваших руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я в ваших руках . <end>
# Predicted translation: i'm in your hands . <end>
# Input: <start> я незаменим . <end>
# Predicted translation: i'm irreplaceable . <end>
